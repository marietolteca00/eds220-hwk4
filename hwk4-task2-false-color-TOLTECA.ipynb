# %% [markdown]
# ### About Data
# Microsoft Planetary Computer, 'https://planetarycomputer.microsoft.com/dataset/landsat-c2-l2', is where our data landsat from Palisades Eaton was retrieved.

# %% [markdown]
# ### Import Libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import netcdf4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 5
#       3 import matplotlib.pyplot as plt
#       4 import geopandas as gpd
# ----> 5 import netcdf4
#
# ModuleNotFoundError: No module named 'netcdf4'

# %% [markdown]
# ### Import Data

# %%
landsat8 = xr.open_dataset('eds220-hwk4/data/landsat8-2025-02-23-palisades-eaton.nc')
landsat8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 landsat8 = xr.open_dataset('eds220-hwk4/data/landsat8-2025-02-23-palisades-eaton.nc')
#       2 landsat8
#
# NameError: name 'xr' is not defined
